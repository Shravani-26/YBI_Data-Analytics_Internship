# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravani-26/YBI_Data-Analytics_Internship/blob/main/Data_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
salary=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Experience Years', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
Y=salary['Salary']
X=salary[['Experience Years']]

# %%
salary.shape
# Out:
# (40, 2)

# %%
X.shape
# Out:
# (40, 1)

# %%
Y.shape
# Out:
# (40,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.7)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 25565.874141587694

# %%
model.coef_
# Out:
# array([9504.11717465])

# %%
model.predict(X_test)
Y_predict=model.predict(X_test)
Y_predict
# Out:
# array([123458.28104053,  39822.04990357,  77838.51860219, 103499.63497375,
#         58830.28425288, 116805.39901827, 111102.92871348,  55979.04910048,
#         60731.10768781,  87342.63577684,  62631.93112274,  75937.69516726])

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(Y_test,Y_predict)
# Out:
# 0.04429889238528196
